# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/libinathomas/repos/test/Datasets/Mobley/info.csv")

# %%
df
# Out:
#     ID   dataset group name Dataset Name  Host    Guest  Ex _G_(kcal/mol)  \
# 0    1  Mobley benchmarkset      cd-set1   acd  guest-1            -1.575
# 1    2  Mobley benchmarkset      cd-set1   acd  guest-2            -3.533
# 2    3  Mobley benchmarkset      cd-set1   acd  guest-3            -4.606
# 3    4  Mobley benchmarkset      cd-set1   acd  guest-4            -2.130
# 4    5  Mobley benchmarkset      cd-set1   acd  guest-5            -2.510
# ..  ..                  ...          ...   ...      ...               ...
# 94  95              pdbbind      refined  1b5j     1b5j            -1.200
# 95  96              pdbbind      refined  1b6h     1b6h            -1.230
# 96  97              pdbbind      refined  1b7h     1b7h            -1.240
# 97  98              pdbbind      refined  1b8n     1b8n            -1.410
# 98  99              pdbbind      refined  1b9j     1b9j            -1.070
#
#     Ex _G_SEM  EX _H_(kcal/mol)  EX _H_SEM  pb_guest_Etot  ...  \
# ...

# %%
df[23:]
# Out:
#     ID   dataset group name Dataset Name  Host    Guest  Ex _G_(kcal/mol)  \
# 23  24  Mobley benchmarkset      cd-set2   bcd  guest-2            -3.585
# 24  25  Mobley benchmarkset      cd-set2   bcd  guest-3            -3.050
# 25  26  Mobley benchmarkset      cd-set2   bcd  guest-4            -4.541
# 26  27  Mobley benchmarkset      cd-set2   bcd  guest-5            -4.560
# 27  28  Mobley benchmarkset      cd-set2   bcd  guest-6            -1.267
# ..  ..                  ...          ...   ...      ...               ...
# 94  95              pdbbind      refined  1b5j     1b5j            -1.200
# 95  96              pdbbind      refined  1b6h     1b6h            -1.230
# 96  97              pdbbind      refined  1b7h     1b7h            -1.240
# 97  98              pdbbind      refined  1b8n     1b8n            -1.410
# 98  99              pdbbind      refined  1b9j     1b9j            -1.070
#
#     Ex _G_SEM  EX _H_(kcal/mol)  EX _H_SEM  pb_guest_Etot  ...  \
# ...

# %%
subset_df = df[df['Host'] == 'acd']

# %%
subset_df
# Out:
#     ID   dataset group name Dataset Name Host     Guest  Ex _G_(kcal/mol)  \
# 0    1  Mobley benchmarkset      cd-set1  acd   guest-1            -1.575
# 1    2  Mobley benchmarkset      cd-set1  acd   guest-2            -3.533
# 2    3  Mobley benchmarkset      cd-set1  acd   guest-3            -4.606
# 3    4  Mobley benchmarkset      cd-set1  acd   guest-4            -2.130
# 4    5  Mobley benchmarkset      cd-set1  acd   guest-5            -2.510
# 5    6  Mobley benchmarkset      cd-set1  acd   guest-6            -1.506
# 6    7  Mobley benchmarkset      cd-set1  acd   guest-7            -3.380
# 7    8  Mobley benchmarkset      cd-set1  acd   guest-8            -4.622
# 8    9  Mobley benchmarkset      cd-set1  acd   guest-9            -1.685
# 9   10  Mobley benchmarkset      cd-set1  acd  guest-10            -1.764
# 10  11  Mobley benchmarkset      cd-set1  acd  guest-11            -2.720
# 11  12  Mobley benchmarkset      cd-set1  acd  guest-12            -3.516
# ...

# %%
subset_df.to_csv('/Users/libinathomas/repos/test/Host_Guest_System/cd-set1.csv', index=False)

# %%
subset_bcd_df = df[df['Host'] == 'bcd']

# %%
subset_bcd_df.to_csv('/Users/libinathomas/repos/test/Host_Guest_System/cd-set2.csv', index =False)

# %%
subset_gdcc_df = df[df['Dataset Name'] == 'gdcc-set1' ]

# %%
subset_gdcc_df
# Out:
#     ID   dataset group name Dataset Name   Host    Guest  Ex _G_(kcal/mol)  \
# 43  44  Mobley benchmarkset    gdcc-set1  temoa  guest-3            -5.476
# 44  45  Mobley benchmarkset    gdcc-set1  temoa  guest-4            -4.520
# 45  46  Mobley benchmarkset    gdcc-set1  temoa  guest-5            -5.260
# 46  47  Mobley benchmarkset    gdcc-set1  temoa  guest-7            -5.730
# 47  48  Mobley benchmarkset    gdcc-set1     oa  guest-3            -5.400
# 48  49  Mobley benchmarkset    gdcc-set1     oa  guest-4            -5.340
# 49  50  Mobley benchmarkset    gdcc-set1     oa  guest-5            -4.730
# 50  51  Mobley benchmarkset    gdcc-set1     oa  guest-6            -9.370
# 51  52  Mobley benchmarkset    gdcc-set1     oa  guest-7            -4.490
# 52  53  Mobley benchmarkset    gdcc-set1     oa  guest-8            -3.720
#
#     Ex _G_SEM  EX _H_(kcal/mol)  EX _H_SEM  pb_guest_Etot  ...  \
# 43      0.006            -9.961      0.006       -75.1661  ...
# ...

# %%
subset_gdcc_df.to_csv('/Users/libinathomas/repos/test/Host_Guest_System/gdcc-set1.csv', index = False)
